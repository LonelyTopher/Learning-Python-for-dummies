# %% [markdown]
# <a href="https://colab.research.google.com/github/LonelyTopher/Learning-Python-for-dummies/blob/main/Chapter_8_Python_for_Dummies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
TestVal = 6

if TestVal == 6:
  print("The TestVal does equal 6")
# Out:
# The TestVal does equal 6

# %%
MyVariable = 8

if MyVariable == 8:
  print("The variables are equal to their values")
  print("All done!")

print(TestVal)
# Out:
# The variables are equal to their values
# All done!
# 6

# %%
Value = int(input("Type a number between 1 and 10: "))

if (Value > 0) and (Value <= 10):
  print("You typed: ", Value)
# Out:
# Type a number between 1 and 10: 7
# You typed:  7

# %%
value = int(input("Type a number between 1 and 10: "))

if (value > 0) and (value <= 10):
  print ("You typed: ", value)

else:
  print("The value you typed is incorrect.")
# Out:
# Type a number between 1 and 10: 25
# The value you typed is incorrect.

# %%
print("1. Red")
print("2. Orange")
print("3. Yellow")
print("4. Green")
print("5. Blue")
print("6. Purple")

Choice = int(input("Select your favorite color: "))
if (Choice == 1):
  print("You chose Red!")
elif (Choice == 2):
  print("You chose Orange!")
elif (Choice == 3):
  print("You chose Yellow!")
elif (Choice == 4):
  print("You chose Green!")
elif (Choice == 5):
  print("You chose Blue!")
elif (Choice == 6):
  print("You chose Purple!")
else:
  print("You made an invalid choice.")
# Out:
# 1. Red
# 2. Orange
# 3. Yellow
# 4. Green
# 5. Blue
# 6. Purple
# Select your favorite color: 6
# You chose Purple!

# %%
One = int(input("Type a number between 1 and 10: "))
Two = int(input("Type another number between 1 and 10: "))

if One >= 1 and (Two <=10):
  if (Two >= 1) and (Two <= 10):
    print("Your secret number is: ", One * Two)
  else:
    print("Incorrect second value!")
else:
  print("Incorrect first value!")
# Out:
# Type a number between 1 and 10: 17
# Type another number between 1 and 10: 10
# Your secret number is:  170

# %%
from concurrent.futures.thread import BrokenThreadPool
print("1. Eggs")
print("2. Pancakes")
print("3. Waffles")
print("4. Oatmeal")

MainChoice = int(input("Choose a breakfast item: "))

if (MainChoice == 2):
  Meal = "Pancakes"
elif (MainChoice == 3):
  Meal = "Waffles"
if (MainChoice == 1):
  print("1. Wheat Toast")
  print("2. Sourdough")
  print("3. Rye Toast")
  print("4. Pancakes")
  Bread = int(input("Choose a type of bread: "))
  if (Bread == 1):
    print("You chose eggs with wheat toast")
  elif (Bread == 2):
    print("You chose eggs with sour dough")
  elif (Bread == 3):
    print("You chose eggs with rye toast")
  else:
    print("We have eggs, but not that kind of bread")
elif (MainChoice == 2) or (MainChoice == 3):
  print("1. Syrup")
  print("2. Strawberries")
  print("3. Powdered Sugar")
  Topping = int(input("Choose a topping: "))
  if (Topping == 1):
    print ("You choise " + Meal + " 1with Syrup")
  elif (Topping == 2):
    print ("You choise " + Meal + "with Strawberries")
  elif (Topping == 3):
    print ("You choise " + Meal + "with Powdered Sugar")
  else:
    print("We have " + Meal + "but not that topping")
elif (MainChoice == 4):
  print("You chose oatmeal.")
else:
  print("We don't serve that breakfast item.")
# Out:
# 1. Eggs
# 2. Pancakes
# 3. Waffles
# 4. Oatmeal
# Choose a breakfast item: 3
# 1. Syrup
# 2. Strawberries
# 3. Powdered Sugar
# Choose a topping: 1
# You choise Waffles with Syrup
