# %% [markdown]
# <a href="https://colab.research.google.com/github/LonelyTopher/Learning-Python-for-dummies/blob/main/Chapter_6" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Talking the talk

# %% [markdown]
# ##Data types and variables

# %%
myInt = int(123)

type(myInt)

print(myInt)
# Out:
# 123

# %%
myInt = int("123")

type(myInt)

print(myInt)
# Out:
# 123

# %%
'''
for some reason the int() function ignores the quotations around a string, only
if the string's value is equal to that of a whole number (i.e. an integer)
'''

myInt = int("The 123")

type(myInt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-538332788.py in <cell line: 0>()
#       3 '''
#       4
# ----> 5 myInt = int("The 123")
#       6
#       7 type(myInt)
#
# ValueError: invalid literal for int() with base 10: 'The 123'

# %% [markdown]
# ##Working with Dates and Times

# %%
import datetime

print(str(datetime.datetime.now().date()))

dir(datetime)

dir(datetime.timezone)
