# %% [markdown]
# <a href="https://colab.research.google.com/github/LonelyTopher/Learning-Python-for-dummies/blob/main/my_first_python_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #My First Program

# %% [markdown]
# ##Developing the code

# %% [markdown]
# This is my first time hard coding with a Python, I plan on becoming an expert programmer/developer

# %%
import inspect

#Define a function to encapsulate task code that accepts
#to pieces of information in boxes called variables
#named value1 and value2
def addSomething(value1, value2,):

  #add the two values together and return the reult
  #to the caller
  return value1 + value2

#Call the addSomething() function with two numbers to
#add and then use print() to display the result
print(addSomething(7, 213))
# Out:
# 220

# %%
YourName = "Christopher" # @param {"type":"string"}
print(f"your name is: {YourName}")
# Out:
# your name is: Christopher

# %%
'''
  Applications: Comments.py
  Written by: Christopher
  purpose: learn how to use comments
'''
print("This is a really long line of text that will " +
      "appear on multiple lines in the source code file")
# Out:
# This is a really long line of text that will appear on multiple lines in the source code file
